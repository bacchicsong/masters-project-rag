# %% [markdown]
# # Assets for the LaTeX presentation
#
# Run this notebook from the repository root or from `research/`. It saves tables and figures to `research/presentation_assets/`. The LaTeX file references these paths but does not embed the images directly in the source text.

# %%
from pathlib import Path
import os

cwd = Path.cwd()
if cwd.name == 'research':
    os.chdir(cwd.parent)
Path.cwd()

# %%
# %run research/presentation_assets.py

# %%
import pandas as pd
assets = Path('research/presentation_assets')
dataset_summary = pd.read_csv(assets / 'dataset_summary.csv')
experiment_results = pd.read_csv(assets / 'experiment_results.csv')
display(dataset_summary)
display(experiment_results)

# %% [markdown]
# Generated files:
#
# - `eda_text_lengths.png`: distribution of chunk lengths for the data slide.
# - `experiment_metrics.png`: comparison of retrieval experiments for ML/DL slides.
# - `dataset_summary.csv`, `experiment_results.csv`, `golden_set_summary.json`: source tables for the presentation.
#
# For the service demo slide, save a 30-40 second recording as `research/presentation_assets/service_demo.gif` or `service_demo.mp4` and uncomment the corresponding media line in the LaTeX slide.
